# %%
cl <- read.csv("Coldplay", header = FALSE)
cl_1 <- cl[order(cl$V2),]
tail(cl_1, 50)
# Out:
#         V1  V2
# 18   could  25
# 103 you're  25
# 202   this  25
# 677     at  25
# 823   they  25
# 154     oh  26
# 711   want  26
# 855    how  27
# 118    are  28
# 385   down  28
# 477     up  28
# 794   i'll  28
# 237   from  30
# 490   love  30
# 787    was  30
# 708   rush  31
# 675    out  32
# 486   such  33
# 135   when  35
# 322   what  36
# 405   it's  36
# 30     see  37
# 570     if  37
# 553    but  38
# 563   just  38
# 233  don't  39
# 334     on  39
# 208     is  40
# 96    know  41
# 491     so  42
# 98      do  43
# 100  never  43
# 480     go  43
# 762    i'm  52
# 117     of  54
# 287    all  54
# 219    for  57
# 347   that  58
# 533     be  60
# 873     me  65
# 503     it  71
# 789   your  74
# 689     my  83
# 853     in  84
# 7        a 134
# 632     to 154
# 758    the 186
# 489    and 238
# 650    you 281
# 389      i 291

# %%
nv <- read.csv("Nirvana", header = FALSE)
nv_1 <- nv[order(nv$V2),]
tail(nv_1, 50)
# Out:
#          V1  V2
# 51     only  12
# 128    dumb  12
# 326    girl  12
# 408   means  12
# 414    just  12
# 456      so  12
# 274     you  13
# 35    knows  14
# 441   where  14
# 495  advice  14
# 237      do  15
# 277      as  15
# 480     sun  15
# 144    been  16
# 290   gonna  16
# 494     but  16
# 42     rape  18
# 132    i've  18
# 134   likes  18
# 30     yeah  19
# 63       it  19
# 250      he  19
# 100    what  20
# 231     one  21
# 50    don't  22
# 174   think  22
# 255  should  26
# 271     are  28
# 295    yeah  28
# 28     your  29
# 239     she  29
# 57    hello  30
# 98      you  31
# 484      we  33
# 251      is  34
# 366      my  36
# 17       to  43
# 64  grandma  43
# 256    home  44
# 382    have  47
# 433    take  49
# 514     not  51
# 53      and  54
# 508      in  60
# 356     all  72
# 214     i'm  77
# 411     the  80
# 462       a  81
# 521      me  82
# 138       i 132

# %%
lb <- read.csv("Limp Bizkit", header = FALSE)
lb$V2 <- as.numeric(lb$V2)
tail(lb[order(lb$V2),], 50)
# Out:
#              V1 V2
# 354         on) 54
# 363       today 54
# 483       wrong 54
# 701        over 54
# 706      what's 54
# 940      little 54
# 952       blame 54
# 980    bullshit 54
# 988       ahead 54
# 998       might 54
# 1061     didn't 54
# 1063       some 54
# 1209       will 54
# 1245       well 54
# 1246        cry 54
# 1278        off 54
# 21         till 55
# 410       leave 55
# 427       won't 55
# 575     highway 55
# 583       i'mma 55
# 652     figured 55
# 765        make 55
# 936         got 55
# 957       guess 55
# 1161       into 55
# 1175      shout 55
# 174        your 56
# 74        stand 57
# 139         hey 57
# 277     (method 57
# 333       right 57
# 592        away 57
# 614        talk 57
# 649      coming 57
# 662         how 57
# 675   everybody 57
# 773  generation 57
# 915      bizkit 57
# 928      change 57
# 943       alone 57
# 1018        too 57
# 1062        say 57
# 1072       stay 57
# 1173     (what) 57
# 1190      maybe 57
# ...

# %% [raw]
# Это неверный результат, т.к. есть и более часто встречающиеся слова. Не знаю, почему такой эффект.

# %% [raw]
# Тексты по жанру:

# %%
at <- read.csv("Alternative", header = FALSE)
at$V2 <- as.numeric(at$V2)
tail(at[order(at$V2),], 50)
# Out:
#             V1  V2
# 603       play 118
# 659     rather 118
# 713         ah 118
# 747    explain 118
# 816     really 118
# 860         it 118
# 1150 priceless 118
# 1171     since 118
# 1190   coldest 118
# 1253     space 118
# 1268    reason 118
# 1294     black 118
# 1350     god's 118
# 1351 dangerous 118
# 1539       two 118
# 1679       bet 118
# 1685       ooh 118
# 1854      full 118
# 1900     right 118
# 1930       hit 118
# 1979      easy 118
# 1983     shoot 118
# 2029  sometime 118
# 2043  breaking 118
# 2054       sit 118
# 2253    turned 118
# 2438     ocean 118
# 2448       set 118
# 2501  tomorrow 118
# 2793     man's 118
# 2803    winter 118
# 2833   memoria 118
# 2922 complaint 118
# 2926      city 118
# 2961  remember 118
# 3044     young 118
# 3196     fight 118
# 3306      work 118
# 3314     feels 118
# 1941       was 119
# 3322       you 120
# 377        see 121
# 868       will 122
# 2251        as 123
# 2433      they 123
# 2368       she 124
# ...
